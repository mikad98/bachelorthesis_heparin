# %% [markdown]
# ## Imports

# %%
import pandas as pd
import dask.dataframe as dd

# %% [markdown]
# ### OUTPUTEVENTS

# %%
df_OUTPUTEVENTS = pd.read_csv('OUTPUTEVENTS.csv')

df_OUTPUTEVENTS.head()
# Out:
#    ROW_ID  SUBJECT_ID   HADM_ID  ICUSTAY_ID            CHARTTIME  ITEMID  \
# 0     344       21219  177991.0    225765.0  2142-09-08 10:00:00   40055
# 1     345       21219  177991.0    225765.0  2142-09-08 12:00:00   40055
# 2     346       21219  177991.0    225765.0  2142-09-08 13:00:00   40055
# 3     347       21219  177991.0    225765.0  2142-09-08 14:00:00   40055
# 4     348       21219  177991.0    225765.0  2142-09-08 16:00:00   40055
#
#    VALUE VALUEUOM            STORETIME   CGID  STOPPED  NEWBOTTLE  ISERROR
# 0  200.0       ml  2142-09-08 12:08:00  17269      NaN        NaN      NaN
# 1  200.0       ml  2142-09-08 12:08:00  17269      NaN        NaN      NaN
# 2  120.0       ml  2142-09-08 13:39:00  17269      NaN        NaN      NaN
# 3  100.0       ml  2142-09-08 16:17:00  17269      NaN        NaN      NaN
# 4  200.0       ml  2142-09-08 16:17:00  17269      NaN        NaN      NaN

# %% [markdown]
# ### D_ITEMS

# %%
df_D_ITEMS = pd.read_csv('D_ITEMS.csv')

df_D_ITEMS[:50]
# Out:
#     ROW_ID  ITEMID                                        LABEL ABBREVIATION  \
# 0      457     497  Patient controlled analgesia (PCA) [Inject]          NaN
# 1      458     498                            PCA Lockout (Min)          NaN
# 2      459     499                               PCA Medication          NaN
# 3      460     500                               PCA Total Dose          NaN
# 4      461     501                           PCV Exh Vt (Obser)          NaN
# 5     1157     927                                    Allergy 2          NaN
# 6     1158     930                                          Ext          NaN
# 7     1159     935                                    Allergy 3          NaN
# 8     1160     938                               blood cultures          NaN
# 9     1161     940                                   trach care          NaN
# 10    1162     941                                urine culture          NaN
# ...

# %%
df_D_ITEMS = pd.read_csv('D_ITEMS.csv')

mask = df_D_ITEMS['LABEL'] == 'heparin'

df_D_ITEMS[mask]
# Out:
#       ROW_ID  ITEMID    LABEL ABBREVIATION DBSOURCE      LINKSTO CATEGORY  \
# 1379    1508    4527  heparin          NaN  carevue  chartevents      NaN
#
#      UNITNAME PARAM_TYPE  CONCEPTID
# 1379      NaN        NaN        NaN

# %%
df_OUTPUTEVENTS = pd.read_csv('OUTPUTEVENTS.csv')

mask = df_OUTPUTEVENTS['ITEMID'] == 4527

df_OUTPUTEVENTS[mask]
# Out:
# Empty DataFrame
# Columns: [ROW_ID, SUBJECT_ID, HADM_ID, ICUSTAY_ID, CHARTTIME, ITEMID, VALUE, VALUEUOM, STORETIME, CGID, STOPPED, NEWBOTTLE, ISERROR]
# Index: []

# %% [markdown]
# ### D_LABITEMS

# %%
df_D_LABITEMS = pd.read_csv('D_LABITEMS.csv')

df_D_LABITEMS.head()
# Out:
#    ROW_ID  ITEMID                       LABEL                      FLUID  \
# 0     546   51346                      Blasts  Cerebrospinal Fluid (CSF)
# 1     547   51347                 Eosinophils  Cerebrospinal Fluid (CSF)
# 2     548   51348             Hematocrit, CSF  Cerebrospinal Fluid (CSF)
# 3     549   51349  Hypersegmented Neutrophils  Cerebrospinal Fluid (CSF)
# 4     550   51350           Immunophenotyping  Cerebrospinal Fluid (CSF)
#
#      CATEGORY LOINC_CODE
# 0  Hematology    26447-3
# 1  Hematology    26451-5
# 2  Hematology    30398-2
# 3  Hematology    26506-6
# 4  Hematology        NaN

# %%
df_D_LABITEMS = pd.read_csv('D_LABITEMS.csv')

mask1 = df_D_LABITEMS['LABEL'] == 'Thrombin'
mask2 = df_D_LABITEMS['LABEL'] == 'PTT'
mask3 = df_D_LABITEMS['LABEL'] == 'PT'
mask4 = df_D_LABITEMS['LABEL'] == 'Fibrinogen'
mask5 = df_D_LABITEMS['LABEL'] == 'inr'
mask6 = df_D_LABITEMS['LABEL'] == 'd_dimer'

display(df_D_LABITEMS[mask1])
display(df_D_LABITEMS[mask2])
display(df_D_LABITEMS[mask3])
display(df_D_LABITEMS[mask4])
display(df_D_LABITEMS[mask5])
display(df_D_LABITEMS[mask6])
# Out:
#      ROW_ID  ITEMID     LABEL  FLUID    CATEGORY LOINC_CODE
# 623     497   51297  Thrombin  Blood  Hematology     3243-3
#      ROW_ID  ITEMID LABEL  FLUID    CATEGORY LOINC_CODE
# 601     475   51275   PTT  Blood  Hematology     3173-2
#      ROW_ID  ITEMID LABEL  FLUID    CATEGORY LOINC_CODE
# 600     474   51274    PT  Blood  Hematology     5902-2
# Empty DataFrame
# Columns: [ROW_ID, ITEMID, LABEL, FLUID, CATEGORY, LOINC_CODE]
# Index: []
# Empty DataFrame
# Columns: [ROW_ID, ITEMID, LABEL, FLUID, CATEGORY, LOINC_CODE]
# Index: []
# Empty DataFrame
# Columns: [ROW_ID, ITEMID, LABEL, FLUID, CATEGORY, LOINC_CODE]
# Index: []

# %% [markdown]
# ### CHARTEVENTS (ohne desk)

# %%
df_CHARTEVENTSpd = pd.read_csv('CHARTEVENTS.csv', usecols=['ITEMID'])
    
mask = df_CHARTEVENTSpd['ITEMID'] == 4527

df_CHARTEVENTSpd[mask]
# Out:
#            ITEMID
# 57012831     4527
# 57012851     4527
# 57104274     4527
# 57104303     4527
# 57110451     4527
# 57129923     4527
# 57136063     4527
# 57154407     4527
# 57175709     4527
# 57175721     4527
# 57185057     4527
# 113534810    4527
# 126812236    4527
# 126825441    4527
# 163287927    4527

# %% [markdown]
# ### CHARTEVENTS (mit desk)

# %%
df_CHARTEVENTSdd = dd.read_csv('CHARTEVENTS.csv', dtype={'CGID': 'float64', 'ICUSTAY_ID': 'float64', 'ERROR': 'float64', 'RESULTSTATUS': 'object', 'STOPPED': 'object', 'VALUE': 'object', 'WARNING': 'float64'})

df_CHARTEVENTSdd.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID  ITEMID            CHARTTIME  \
# 0     788          36   165660    241249.0  223834  2134-05-12 12:00:00
# 1     789          36   165660    241249.0  223835  2134-05-12 12:00:00
# 2     790          36   165660    241249.0  224328  2134-05-12 12:00:00
# 3     791          36   165660    241249.0  224329  2134-05-12 12:00:00
# 4     792          36   165660    241249.0  224330  2134-05-12 12:00:00
#
#              STORETIME     CGID VALUE  VALUENUM VALUEUOM  WARNING  ERROR  \
# 0  2134-05-12 13:56:00  17525.0    15     15.00    L/min      0.0    0.0
# 1  2134-05-12 13:56:00  17525.0   100    100.00      NaN      0.0    0.0
# 2  2134-05-12 12:18:00  20823.0   .37      0.37      NaN      0.0    0.0
# 3  2134-05-12 12:19:00  20823.0     6      6.00      min      0.0    0.0
# 4  2134-05-12 12:19:00  20823.0   2.5      2.50      NaN      0.0    0.0
#
#   RESULTSTATUS STOPPED
# 0          NaN     NaN
# 1          NaN     NaN
# ...

# %%
mask = df_CHARTEVENTSdd['ITEMID'] == 4527

df_CHARTEVENTSdd[mask].compute()
# Out:
# C:\Users\mikad\anaconda3\lib\site-packages\dask\core.py:118: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   args2 = [_execute_task(a, cache) for a in args]
#            ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID  ITEMID  \
# 68817    57003164        4453   102256    237950.0    4527
# 68837    57003184        4453   102256    237950.0    4527
# 160260   57002862        4453   102256    237950.0    4527
# 160289   57002891        4453   102256    237950.0    4527
# 166437   57002916        4453   102256    237950.0    4527
# 185909   57003070        4453   102256    237950.0    4527
# 192049   57003088        4453   102256    237950.0    4527
# 210393   57003016        4453   102256    237950.0    4527
# 231695   57003239        4453   102256    237950.0    4527
# 231707   57003251        4453   102256    237950.0    4527
# 241043   57002973        4453   102256    237950.0    4527
# ...

# %% [markdown]
# ### Labevents

# %%
df_LABEVENTS = pd.read_csv('LABEVENTS.csv')

df_LABEVENTS.head(10)
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ITEMID            CHARTTIME          VALUE  \
# 0     281           3      NaN   50820  2101-10-12 16:07:00           7.39
# 1     282           3      NaN   50800  2101-10-12 18:17:00            ART
# 2     283           3      NaN   50802  2101-10-12 18:17:00             -1
# 3     284           3      NaN   50804  2101-10-12 18:17:00             22
# 4     285           3      NaN   50808  2101-10-12 18:17:00           0.93
# 5     286           3      NaN   50812  2101-10-12 18:17:00  NOT INTUBATED
# 6     287           3      NaN   50813  2101-10-12 18:17:00            1.8
# 7     288           3      NaN   50818  2101-10-12 18:17:00             33
# 8     289           3      NaN   50820  2101-10-12 18:17:00           7.42
# 9     290           3      NaN   50821  2101-10-12 18:17:00             80
#
#    VALUENUM VALUEUOM      FLAG
# 0      7.39    units       NaN
# 1       NaN      NaN       NaN
# 2     -1.00    mEq/L       NaN
# ...
